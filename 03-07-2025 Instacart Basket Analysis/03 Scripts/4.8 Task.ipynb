# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# make a path to project folder
path = r'C:\Users\egrnw\anaconda3\03-07-2025 Instacart Basket Analysis'

# %%
#Import orders_products_merge_variables
ords_prods_merge = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_variables.csv'))

# %%
ords_prods_merge.shape
# Out:
# (1000000, 22)

# %%
ords_prods_merge.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0           0             0   2539329        1    prior             1
# 1           1             0   2539329        1    prior             1
# 2           2             0   2539329        1    prior             1
# 3           3             0   2539329        1    prior             1
# 4           4             0   2539329        1    prior             1
# 5           5             1   2398795        1    prior             2
# 6           6             1   2398795        1    prior             2
# 7           7             1   2398795        1    prior             2
# 8           8             1   2398795        1    prior             2
# 9           9             1   2398795        1    prior             2
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# ...

# %% [markdown]
# # 2.

# %%
# Group by department_id and order_number
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %% [markdown]
# # 3.

# %% [markdown]
# The results look the same. I may have made an error in saving the previous exercise.

# %% [markdown]
# # 4.

# %%
# aggregate data
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\egrnw\AppData\Local\Temp\ipykernel_22836\1681540670.py:1: FutureWarning: The provided callable <function max at 0x00000242A1A12FC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0            0             0   2539329        1    prior             1
# 1            1             0   2539329        1    prior             1
# 2            2             0   2539329        1    prior             1
# 3            3             0   2539329        1    prior             1
# 4            4             0   2539329        1    prior             1
# 5            5             1   2398795        1    prior             2
# 6            6             1   2398795        1    prior             2
# 7            7             1   2398795        1    prior             2
# 8            8             1   2398795        1    prior             2
# 9            9             1   2398795        1    prior             2
# 10          10             1   2398795        1    prior             2
# 11          11             2    473747        1    prior             3
# ...

# %%
# Loyal customer flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Regular customer flag
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# New customer flag
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# value count
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    482391
# Loyal customer      322011
# New customer        195598
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %% [markdown]
# # 5.

# %%
# spending habits of 3 types of customers
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer     9.081626  1.0  99999.0
# New customer      15.843383  1.0  99999.0
# Regular customer  11.139256  1.0  99999.0

# %% [markdown]
# It appears that Loyal customers purchase lower cost items compared to regular customers on average. New customers seem to be purchasing more expensive items. However the high max on all three indicates that their are outliers or errors in the data.

# %% [markdown]
# # 6.

# %%
# aggregate data
ords_prods_merge['avg_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\egrnw\AppData\Local\Temp\ipykernel_22836\1439671318.py:2: FutureWarning: The provided callable <function mean at 0x00000242A1A139C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge[['user_id', 'avg_product_price']].head(15)
# Out:
#     user_id  avg_product_price
# 0         1           6.367797
# 1         1           6.367797
# 2         1           6.367797
# 3         1           6.367797
# 4         1           6.367797
# 5         1           6.367797
# 6         1           6.367797
# 7         1           6.367797
# 8         1           6.367797
# 9         1           6.367797
# 10        1           6.367797
# 11        1           6.367797
# 12        1           6.367797
# 13        1           6.367797
# 14        1           6.367797

# %%
# low spender flag
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# High spender flag
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     978614
# High spender     21386
# Name: count, dtype: int64

# %%
# column check
ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(15)
# Out:
#     user_id  avg_product_price spending_flag
# 0         1           6.367797   Low spender
# 1         1           6.367797   Low spender
# 2         1           6.367797   Low spender
# 3         1           6.367797   Low spender
# 4         1           6.367797   Low spender
# 5         1           6.367797   Low spender
# 6         1           6.367797   Low spender
# 7         1           6.367797   Low spender
# 8         1           6.367797   Low spender
# 9         1           6.367797   Low spender
# 10        1           6.367797   Low spender
# 11        1           6.367797   Low spender
# 12        1           6.367797   Low spender
# 13        1           6.367797   Low spender
# 14        1           6.367797   Low spender

# %% [markdown]
# # 7.

# %%
# aggregate data
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\egrnw\AppData\Local\Temp\ipykernel_22836\2108406739.py:2: FutureWarning: The provided callable <function median at 0x00000242A1C26F20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# column check
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0         1                     NaN                        20.5
# 1         1                     NaN                        20.5
# 2         1                     NaN                        20.5
# 3         1                     NaN                        20.5
# 4         1                     NaN                        20.5
# 5         1                    15.0                        20.5
# 6         1                    15.0                        20.5
# 7         1                    15.0                        20.5
# 8         1                    15.0                        20.5
# 9         1                    15.0                        20.5
# 10        1                    15.0                        20.5
# 11        1                    21.0                        20.5
# 12        1                    21.0                        20.5
# 13        1                    21.0                        20.5
# ...

# %%
# non frequent customer flag
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# regular customer flag
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
# frequent customer flag
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# value count
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        664849
# Regular customer         219649
# Non-frequent customer    115502
# Name: count, dtype: int64

# %%
# column check
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0         1                     NaN                        20.5
# 1         1                     NaN                        20.5
# 2         1                     NaN                        20.5
# 3         1                     NaN                        20.5
# 4         1                     NaN                        20.5
# 5         1                    15.0                        20.5
# 6         1                    15.0                        20.5
# 7         1                    15.0                        20.5
# 8         1                    15.0                        20.5
# 9         1                    15.0                        20.5
# 10        1                    15.0                        20.5
# 11        1                    21.0                        20.5
# 12        1                    21.0                        20.5
# 13        1                    21.0                        20.5
# ...

# %% [markdown]
# # 9.

# %%
# export
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_grouped.pkl'))
